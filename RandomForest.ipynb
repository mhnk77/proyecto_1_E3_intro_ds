# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.svm import SVC

# %%
from pytictoc import TicToc
t = TicToc()

# %% [markdown]
# ### Cargar data

# %%
infile = open('data_rf.pickle','rb')
data_rf = pickle.load(infile)
infile.close()

# %%
data_rf
# Out:
#         delegacion_inicio                     incidente_c4     tipo_entrada  \
# 1164271    alvaro obregon            lesionado_atropellado  llamada_del_066
# 1164423    alvaro obregon  accidente_choque_sin_lesionados  llamada_del_066
# 372612     alvaro obregon  accidente_choque_con_lesionados  llamada_del_066
# 372622     alvaro obregon  accidente_choque_sin_lesionados  llamada_del_066
# 372628     alvaro obregon  accidente_choque_sin_lesionados  llamada_del_066
# ...                   ...                              ...              ...
# 1380319        xochimilco  accidente_choque_sin_lesionados  llamada_del_911
# 1382406        xochimilco  accidente_choque_sin_lesionados  llamada_del_911
# 1382445        xochimilco  accidente_choque_con_lesionados  llamada_del_911
# 1382469        xochimilco  accidente_choque_con_lesionados  llamada_del_911
# 1382490           tlalpan           accidente_motociclista  llamada_del_911
#
#          dow_creacion  hora_creacion  mes_creacion            geopoint  label
# 1164271             1             23            12  -99.25598,19.33929      0
# 1164423             1             18            12   -99.2009,19.37831      1
# 372612              2             21             1  -99.19104,19.36336      0
# 372622              2             21             1  -99.19145,19.36348      0
# 372628              2              6             1  -99.20009,19.38161      0
# ...               ...            ...           ...                 ...    ...
# 1380319             5              6            10  -99.12949,19.28373      0
# 1382406             5             21            10  -99.10249,19.29447      0
# 1382445             5             20            10  -99.13296,19.21005      1
# 1382469             5              7            10  -99.12949,19.28373      0
# 1382490             5              1            10  -99.13831,19.28243      0
#
# [1382534 rows x 8 columns]

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Incidentes

# %%
incidentes_top = data_rf.incidente_c4.value_counts().head(7).reset_index(name = "n")['index'].values
incidentes_top
# Out:
# array(['accidente_choque_sin_lesionados',
#        'accidente_choque_con_lesionados', 'lesionado_atropellado',
#        'accidente_motociclista', 'accidente_volcadura',
#        'lesionado_accidente_automovilistico',
#        'accidente_persona_atrapada_desbarrancada'], dtype=object)

# %%
data_rf[data_rf['incidente_c4'].isin(incidentes_top)]
# Out:
#         delegacion_inicio                     incidente_c4     tipo_entrada  \
# 1164271    alvaro obregon            lesionado_atropellado  llamada_del_066
# 1164423    alvaro obregon  accidente_choque_sin_lesionados  llamada_del_066
# 372612     alvaro obregon  accidente_choque_con_lesionados  llamada_del_066
# 372622     alvaro obregon  accidente_choque_sin_lesionados  llamada_del_066
# 372628     alvaro obregon  accidente_choque_sin_lesionados  llamada_del_066
# ...                   ...                              ...              ...
# 1380319        xochimilco  accidente_choque_sin_lesionados  llamada_del_911
# 1382406        xochimilco  accidente_choque_sin_lesionados  llamada_del_911
# 1382445        xochimilco  accidente_choque_con_lesionados  llamada_del_911
# 1382469        xochimilco  accidente_choque_con_lesionados  llamada_del_911
# 1382490           tlalpan           accidente_motociclista  llamada_del_911
#
#          dow_creacion  hora_creacion  mes_creacion            geopoint  label
# 1164271             1             23            12  -99.25598,19.33929      0
# 1164423             1             18            12   -99.2009,19.37831      1
# 372612              2             21             1  -99.19104,19.36336      0
# 372622              2             21             1  -99.19145,19.36348      0
# 372628              2              6             1  -99.20009,19.38161      0
# ...               ...            ...           ...                 ...    ...
# 1380319             5              6            10  -99.12949,19.28373      0
# 1382406             5             21            10  -99.10249,19.29447      0
# 1382445             5             20            10  -99.13296,19.21005      1
# 1382469             5              7            10  -99.12949,19.28373      0
# 1382490             5              1            10  -99.13831,19.28243      0
#
# [1367565 rows x 8 columns]

# %%
data_rf['incidente'] = np.where((data_rf['incidente_c4'].isin(incidentes_top)) ,data_rf['incidente_c4'],"otros" )

data_rf['incidente'].value_counts()
# Out:
# accidente_choque_sin_lesionados             760243
# accidente_choque_con_lesionados             314883
# lesionado_atropellado                       193436
# accidente_motociclista                       55594
# accidente_volcadura                          31754
# otros                                        14969
# lesionado_accidente_automovilistico           6053
# accidente_persona_atrapada_desbarrancada      5602
# Name: incidente, dtype: int64

# %% [markdown]
# ### Geopoints

# %%
geopoints_top = data_rf.geopoint.value_counts().reset_index(name = "n").query('n >= 300')['index'].values

#geopoints_top

# %%
data_rf['tipo_geopoint'] = np.where((data_rf['geopoint'].isin(geopoints_top)) , "frecuente","aislado" )

data_rf['tipo_geopoint'].value_counts()
# Out:
# aislado      1246332
# frecuente     136202
# Name: tipo_geopoint, dtype: int64

# %% [markdown]
# ### Tipo_entrada

# %%
tipo_entrada_top = data_rf.tipo_entrada.value_counts().head(4).reset_index(name = "n")['index'].values
tipo_entrada_top
# Out:
# array(['llamada_del_911', 'llamada_del_066', 'boton_de_auxilio', 'radio'],
#       dtype=object)

# %%
data_rf['tipo_entrada_mod'] = np.where((data_rf['tipo_entrada'].isin(tipo_entrada_top)) ,data_rf['tipo_entrada'],"otros" )

data_rf['tipo_entrada_mod'].value_counts()
# Out:
# llamada_del_911     738879
# llamada_del_066     463374
# boton_de_auxilio     78609
# radio                77698
# otros                23974
# Name: tipo_entrada_mod, dtype: int64

# %% [markdown]
# ### Delegacion inicio

# %%
data_rf['delegacion_inicio'] = data_rf['delegacion_inicio'].str.replace(" ", "_", regex = True)

# %% [markdown]
# ### Conservar variables necesarias

# %%
data_rf = data_rf.drop(columns = ['geopoint','incidente_c4','tipo_entrada'])

data_rf
# Out:
#         delegacion_inicio  dow_creacion  hora_creacion  mes_creacion  label  \
# 1164271    alvaro_obregon             1             23            12      0
# 1164423    alvaro_obregon             1             18            12      1
# 372612     alvaro_obregon             2             21             1      0
# 372622     alvaro_obregon             2             21             1      0
# 372628     alvaro_obregon             2              6             1      0
# ...                   ...           ...            ...           ...    ...
# 1380319        xochimilco             5              6            10      0
# 1382406        xochimilco             5             21            10      0
# 1382445        xochimilco             5             20            10      1
# 1382469        xochimilco             5              7            10      0
# 1382490           tlalpan             5              1            10      0
#
#                                incidente tipo_geopoint tipo_entrada_mod
# 1164271            lesionado_atropellado       aislado  llamada_del_066
# 1164423  accidente_choque_sin_lesionados       aislado  llamada_del_066
# 372612   accidente_choque_con_lesionados     frecuente  llamada_del_066
# 372622   accidente_choque_sin_lesionados       aislado  llamada_del_066
# 372628   accidente_choque_sin_lesionados       aislado  llamada_del_066
# ...                                  ...           ...              ...
# 1380319  accidente_choque_sin_lesionados       aislado  llamada_del_911
# 1382406  accidente_choque_sin_lesionados     frecuente  llamada_del_911
# 1382445  accidente_choque_con_lesionados       aislado  llamada_del_911
# 1382469  accidente_choque_con_lesionados       aislado  llamada_del_911
# 1382490           accidente_motociclista       aislado  llamada_del_911
#
# [1382534 rows x 8 columns]

# %% [markdown]
# ### Encoding

# %%
data_encoded = pd.get_dummies(data_rf, columns = ['delegacion_inicio', 'incidente', 'tipo_geopoint', 'tipo_entrada_mod'])
data_encoded
# Out:
#          dow_creacion  hora_creacion  mes_creacion  label  \
# 1164271             1             23            12      0
# 1164423             1             18            12      1
# 372612              2             21             1      0
# 372622              2             21             1      0
# 372628              2              6             1      0
# ...               ...            ...           ...    ...
# 1380319             5              6            10      0
# 1382406             5             21            10      0
# 1382445             5             20            10      1
# 1382469             5              7            10      0
# 1382490             5              1            10      0
#
#          delegacion_inicio_alvaro_obregon  delegacion_inicio_azcapotzalco  \
# 1164271                                 1                               0
# 1164423                                 1                               0
# 372612                                  1                               0
# 372622                                  1                               0
# 372628                                  1                               0
# ...                                   ...                             ...
# 1380319                                 0                               0
# 1382406                                 0                               0
# 1382445                                 0                               0
# 1382469                                 0                               0
# 1382490                                 0                               0
#
#          delegacion_inicio_benito_juarez  delegacion_inicio_coyoacan  \
# 1164271                                0                           0
# 1164423                                0                           0
# 372612                                 0                           0
# 372622                                 0                           0
# 372628                                 0                           0
# ...                                  ...                         ...
# 1380319                                0                           0
# 1382406                                0                           0
# 1382445                                0                           0
# 1382469                                0                           0
# 1382490                                0                           0
#
#          delegacion_inicio_cuajimalpa  delegacion_inicio_cuauhtemoc  ...  \
# 1164271                             0                             0  ...
# 1164423                             0                             0  ...
# 372612                              0                             0  ...
# 372622                              0                             0  ...
# 372628                              0                             0  ...
# ...                               ...                           ...  ...
# 1380319                             0                             0  ...
# 1382406                             0                             0  ...
# 1382445                             0                             0  ...
# 1382469                             0                             0  ...
# 1382490                             0                             0  ...
#
#          incidente_lesionado_accidente_automovilistico  \
# 1164271                                              0
# 1164423                                              0
# 372612                                               0
# 372622                                               0
# 372628                                               0
# ...                                                ...
# 1380319                                              0
# 1382406                                              0
# 1382445                                              0
# 1382469                                              0
# 1382490                                              0
#
#          incidente_lesionado_atropellado  incidente_otros  \
# 1164271                                1                0
# 1164423                                0                0
# 372612                                 0                0
# 372622                                 0                0
# 372628                                 0                0
# ...                                  ...              ...
# 1380319                                0                0
# 1382406                                0                0
# 1382445                                0                0
# 1382469                                0                0
# 1382490                                0                0
#
#          tipo_geopoint_aislado  tipo_geopoint_frecuente  \
# 1164271                      1                        0
# 1164423                      1                        0
# 372612                       0                        1
# 372622                       1                        0
# 372628                       1                        0
# ...                        ...                      ...
# 1380319                      1                        0
# 1382406                      0                        1
# 1382445                      1                        0
# 1382469                      1                        0
# 1382490                      1                        0
#
#          tipo_entrada_mod_boton_de_auxilio  tipo_entrada_mod_llamada_del_066  \
# 1164271                                  0                                 1
# 1164423                                  0                                 1
# 372612                                   0                                 1
# 372622                                   0                                 1
# 372628                                   0                                 1
# ...                                    ...                               ...
# 1380319                                  0                                 0
# 1382406                                  0                                 0
# 1382445                                  0                                 0
# 1382469                                  0                                 0
# 1382490                                  0                                 0
#
#          tipo_entrada_mod_llamada_del_911  tipo_entrada_mod_otros  \
# 1164271                                 0                       0
# 1164423                                 0                       0
# 372612                                  0                       0
# 372622                                  0                       0
# 372628                                  0                       0
# ...                                   ...                     ...
# 1380319                                 1                       0
# 1382406                                 1                       0
# 1382445                                 1                       0
# 1382469                                 1                       0
# 1382490                                 1                       0
#
#          tipo_entrada_mod_radio
# 1164271                       0
# 1164423                       0
# 372612                        0
# 372622                        0
# 372628                        0
# ...                         ...
# 1380319                       0
# 1382406                       0
# 1382445                       0
# 1382469                       0
# 1382490                       0
#
# [1382534 rows x 35 columns]

# %% [markdown]
# ### Separar variable de respuesta del resto

# %%
x_data = data_encoded.drop(columns= ['label'])

# %%
y_data = data_encoded['label']

# %% [markdown]
# ### Dividir data en train test

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, random_state=42)

# %%
y_train.value_counts(normalize = True)
# Out:
# 0    0.795943
# 1    0.204057
# Name: label, dtype: float64

# %%
y_test.value_counts(normalize = True)
# Out:
# 0    0.796017
# 1    0.203983
# Name: label, dtype: float64

# %% [markdown]
# ### Definir RF

# %%
rfc=RandomForestClassifier(random_state=42)

# %%
param_grid = { 
    'n_estimators': [200],
    'max_features': [5,6,7,8,9],
    'max_depth' : [20,25],
    'criterion': ['gini']
}

# %%
param_grid
# Out:
# {'n_estimators': [100, 200],
#  'max_features': [4, 5, 6, 7, 8],
#  'criterion': ['gini']}

# %%
#CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5, scoring = 'precision', n_jobs= 3)

# %%
t.tic()
#CV_rfc.fit(x_train, y_train)
t.toc()
# Out:
# Elapsed time is 0.000046 seconds.

# %%
#CV_rfc.best_params_

# %%
rfc1 = RandomForestClassifier(random_state =42, max_features = 8, n_estimators = 200, criterion = 'gini', max_depth=20)

# %%
t.tic()
rfc1.fit(x_train, y_train)
t.toc()
# Out:
# Elapsed time is 243.332920 seconds.

# %%
pred=rfc1.predict(x_test)

# %%
pd.DataFrame(pred).value_counts()
# Out:
# 0    411613
# 1      3148
# dtype: int64

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print("Accuracy for Random Forest on CV data: ",accuracy_score(y_test,pred))
# Out:
# Accuracy for Random Forest on CV data:  0.7948071298892615

# %%
pred_train=rfc1.predict(x_train)

# %%
accuracy_score(y_train,pred_train)
# Out:
# 0.805647605378534

# %%
precision_score(y_train,pred_train)
# Out:
# 0.6790179932906374

# %%
print("Precision for Random Forest on CV data: ",precision_score(y_test,pred))
# Out:
# Precision for Random Forest on CV data:  0.4202668360864041

# %%
d_imp = {'feature': x_train.columns, 'importance': rfc1.feature_importances_}

pd.DataFrame(d_imp).sort_values(by = 'importance', ascending = False)
# Out:
#                                               feature  importance
# 1                                       hora_creacion    0.383408
# 2                                        mes_creacion    0.275765
# 0                                        dow_creacion    0.160852
# 20          incidente_accidente_choque_sin_lesionados    0.038413
# 31                  tipo_entrada_mod_boton_de_auxilio    0.018666
# 35                             tipo_entrada_mod_radio    0.016870
# 19          incidente_accidente_choque_con_lesionados    0.011252
# 27                    incidente_lesionado_atropellado    0.008493
# 33                   tipo_entrada_mod_llamada_del_911    0.007933
# 32                   tipo_entrada_mod_llamada_del_066    0.007618
# 8                        delegacion_inicio_cuauhtemoc    0.004490
# 7                        delegacion_inicio_cuajimalpa    0.004339
# 16                          delegacion_inicio_tlalpan    0.004178
# 11                       delegacion_inicio_iztapalapa    0.003778
# 13                   delegacion_inicio_miguel_hidalgo    0.003640
# 9                 delegacion_inicio_gustavo_a._madero    0.003591
# 25                      incidente_accidente_volcadura    0.003573
# 6                          delegacion_inicio_coyoacan    0.003546
# 3                    delegacion_inicio_alvaro_obregon    0.003438
# 4                      delegacion_inicio_azcapotzalco    0.003202
# 17              delegacion_inicio_venustiano_carranza    0.003180
# 15                          delegacion_inicio_tlahuac    0.003167
# 5                     delegacion_inicio_benito_juarez    0.003124
# 18                       delegacion_inicio_xochimilco    0.003017
# 10                        delegacion_inicio_iztacalco    0.002885
# 12              delegacion_inicio_magdalena_contreras    0.002731
# 22                   incidente_accidente_motociclista    0.002538
# 30                            tipo_geopoint_frecuente    0.002453
# 34                             tipo_entrada_mod_otros    0.002440
# 29                              tipo_geopoint_aislado    0.002291
# 14                       delegacion_inicio_milpa_alta    0.001434
# 28                                    incidente_otros    0.001116
# 24  incidente_accidente_persona_atrapada_desbarran...    0.000881
# 23                          incidente_accidente_otros    0.000669
# 26      incidente_lesionado_accidente_automovilistico    0.000594
# 21                       incidente_accidente_ciclista    0.000437
