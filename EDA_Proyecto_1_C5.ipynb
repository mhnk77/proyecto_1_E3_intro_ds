# %% [markdown]
# ### Leer Datos

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/incidentes-viales-c5.csv')
data.head()
# Out:
#              folio fecha_creacion hora_creacion dia_semana  \
# 0  GA/160123/05714     23/01/2016      22:35:04     Sábado
# 1  AO/160123/05826     23/01/2016      22:50:49     Sábado
# 2  C4/160124/02187     24/01/2016      09:40:11    Domingo
# 3  C4/160124/05723     24/01/2016      22:40:57    Domingo
# 4  C4/160124/01334     24/01/2016      04:25:15    Domingo
#
#                                        codigo_cierre fecha_cierre  año_cierre  \
# 0  (A) La unidad de atención a emergencias fue de...   24/01/2016        2016
# 1  (A) La unidad de atención a emergencias fue de...   24/01/2016        2016
# 2  (N) La unidad de atención a emergencias fue de...   24/01/2016        2016
# 3  (N) La unidad de atención a emergencias fue de...   24/01/2016        2016
# 4  (A) La unidad de atención a emergencias fue de...   24/01/2016        2016
#
#   mes_cierre hora_cierre    delegacion_inicio  \
# 0      Enero    00:21:08  VENUSTIANO CARRANZA
# 1      Enero    04:40:37           CUAJIMALPA
# 2      Enero    11:13:03              TLALPAN
# 3      Enero    22:55:51  MAGDALENA CONTRERAS
# 4      Enero    05:03:59       MIGUEL HIDALGO
#
#                       incidente_c4    latitud   longitud  clas_con_f_alarma  \
# 0  accidente-choque sin lesionados  19.422113 -99.084643         EMERGENCIA
# 1  accidente-choque con lesionados  19.358320 -99.297641  URGENCIAS MEDICAS
# 2  accidente-choque sin lesionados  19.217070 -99.219070         EMERGENCIA
# 3  accidente-choque sin lesionados  19.320580 -99.241010         EMERGENCIA
# 4  accidente-choque sin lesionados  19.452900 -99.215870         EMERGENCIA
#
#        tipo_entrada    delegacion_cierre                  geopoint  mes
# 0  BOTÓN DE AUXILIO  VENUSTIANO CARRANZA      19.422113,-99.084643    1
# 1  BOTÓN DE AUXILIO           CUAJIMALPA       19.35832,-99.297641    1
# 2   LLAMADA DEL 066              TLALPAN     19.21707,-99.21907008    1
# 3   LLAMADA DEL 066  MAGDALENA CONTRERAS  19.32057999,-99.24100992    1
# 4   LLAMADA DEL 066       MIGUEL HIDALGO  19.45289997,-99.21587004    1

# %%
data.dtypes
# Out:
# folio                 object
# fecha_creacion        object
# hora_creacion         object
# dia_semana            object
# codigo_cierre         object
# fecha_cierre          object
# año_cierre             int64
# mes_cierre            object
# hora_cierre           object
# delegacion_inicio     object
# incidente_c4          object
# latitud              float64
# longitud             float64
# clas_con_f_alarma     object
# tipo_entrada          object
# delegacion_cierre     object
# geopoint              object
# mes                    int64
# dtype: object

# %%
data.nunique(axis = 0)
# Out:
# folio                1383138
# fecha_creacion          2637
# hora_creacion         105887
# dia_semana                 7
# codigo_cierre              5
# fecha_cierre            2621
# año_cierre                 7
# mes_cierre                12
# hora_cierre           106827
# delegacion_inicio         16
# incidente_c4              26
# latitud                82501
# longitud               78984
# clas_con_f_alarma          4
# tipo_entrada               9
# delegacion_cierre         16
# geopoint              134288
# mes                       12
# dtype: int64

# %% [markdown]
# ### Cambiar el tipo de variable según corresponda

# %%
data_clean = data.copy(deep = True) #Copy deep para que los cambios hechos a data_clean no se vean reflejados en data

#Existen renglones en los que el formato de fecha es "dd/mm/aa" en vez de "dd/mm/aaaa", para ambias variables de fecha
#Corregimos esto mediante:

data_clean['fecha_creacion'] = data['fecha_creacion'].replace("/19$", "/2019", regex = True, inplace = False) 
data_clean['fecha_creacion'] = data_clean['fecha_creacion'].replace("/18$", "/2018", regex = True, inplace = False) 
data_clean['fecha_cierre'] = data['fecha_cierre'].replace("/19$", "/2019", regex = True, inplace = False) 
data_clean['fecha_cierre'] = data_clean['fecha_cierre'].replace("/18$", "/2018", regex = True, inplace = False)

# %%
#Convertir en fecha las variables correspondientes
data_clean['fecha_creacion'] = pd.to_datetime(data_clean['fecha_creacion'], format = '%d/%m/%Y')
data_clean['fecha_cierre'] = pd.to_datetime(data_clean['fecha_cierre'], format = '%d/%m/%Y')

#Transformar a minusculas las delegaciones
data_clean['delegacion_inicio'] = data.delegacion_inicio.str.lower()
data_clean['delegacion_cierre'] = data.delegacion_cierre.str.lower()

## Modificar incidente c4
#Quitar mayúsculas
data_clean['incidente_c4'] = data_clean['incidente_c4'].str.lower()
#Quitar acentos
data_clean['incidente_c4'] = data_clean['incidente_c4'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
#Quitar " /"
data_clean['incidente_c4'] = data_clean['incidente_c4'].str.replace(' /','', regex =  True)
#Cambiar espacios y "-" por "_"
data_clean['incidente_c4'] = data_clean['incidente_c4'].str.replace('\-|\s','_', regex =  True)

#Conservar únicamente la letra del codigo_cierre
data_clean['codigo_cierre'] = data_clean['codigo_cierre'].str.extract(r'(\(.\))')
data_clean['codigo_cierre'] = data_clean['codigo_cierre'].str.replace('\(|\)', '', regex = True)

#Eliminar la columna "geopoint" pues ya tenemos long. y lat.
data_clean.drop(columns = ['geopoint'], inplace = True)

#Ordenar por delegacion_cierre
data_clean.sort_values(by = ['delegacion_cierre', 'fecha_creacion'], inplace = True)

data_clean.head()
# Out:
#                    folio fecha_creacion hora_creacion dia_semana  \
# 1164271  C4/131231/03508     2013-12-31      23:21:38     Martes
# 1164423  C4/131231/02371     2013-12-31      18:21:47     Martes
# 372612   C4/140101/04189     2014-01-01      21:45:43  Miércoles
# 372622   C4/140101/04201     2014-01-01      21:46:46  Miércoles
# 372628   C4/140101/01293     2014-01-01      06:50:48  Miércoles
#
#         codigo_cierre fecha_cierre  año_cierre mes_cierre hora_cierre  \
# 1164271             A   2014-01-01        2014      Enero    01:01:03
# 1164423             N   2014-01-02        2014      Enero    00:26:07
# 372612              A   2014-01-01        2014      Enero    23:55:59
# 372622              A   2014-01-01        2014      Enero    21:53:16
# 372628              A   2014-01-01        2014      Enero    08:45:49
#
#         delegacion_inicio                     incidente_c4   latitud  \
# 1164271    alvaro obregon            lesionado_atropellado  19.33929
# 1164423    alvaro obregon  accidente_choque_sin_lesionados  19.37831
# 372612     alvaro obregon  accidente_choque_con_lesionados  19.36336
# 372622     alvaro obregon  accidente_choque_sin_lesionados  19.36348
# 372628     alvaro obregon  accidente_choque_sin_lesionados  19.38161
#
#          longitud  clas_con_f_alarma     tipo_entrada delegacion_cierre  mes
# 1164271 -99.25598  URGENCIAS MEDICAS  LLAMADA DEL 066    alvaro obregon    1
# 1164423 -99.20090         EMERGENCIA  LLAMADA DEL 066    alvaro obregon    1
# 372612  -99.19104  URGENCIAS MEDICAS  LLAMADA DEL 066    alvaro obregon    1
# 372622  -99.19145         EMERGENCIA  LLAMADA DEL 066    alvaro obregon    1
# 372628  -99.20009         EMERGENCIA  LLAMADA DEL 066    alvaro obregon    1

# %%
data_clean.dtypes
# Out:
# folio                        object
# fecha_creacion       datetime64[ns]
# hora_creacion                object
# dia_semana                   object
# codigo_cierre                object
# fecha_cierre         datetime64[ns]
# año_cierre                    int64
# mes_cierre                   object
# hora_cierre                  object
# delegacion_inicio            object
# incidente_c4                 object
# latitud                     float64
# longitud                    float64
# clas_con_f_alarma            object
# tipo_entrada                 object
# delegacion_cierre            object
# mes                           int64
# dtype: object

# %% [markdown]
# ### Ver valores faltantes

# %%
data_clean.isna().sum()
# Out:
# folio                  0
# fecha_creacion         0
# hora_creacion          0
# dia_semana             0
# codigo_cierre          0
# fecha_cierre           0
# año_cierre             0
# mes_cierre             0
# hora_cierre            0
# delegacion_inicio    158
# incidente_c4           0
# latitud              443
# longitud             435
# clas_con_f_alarma      0
# tipo_entrada           0
# delegacion_cierre    140
# mes                    0
# dtype: int64

# %% [markdown]
# #### Valores faltantes en delegacion_inicio

# %% [markdown]
# Veamos a qué se deben los NAs en delegacion.
# Lo observamos en la data original para descartar que los NAs hayan sido causados por la transformación de las columnas

# %%
data[data.delegacion_inicio.isna()].clas_con_f_alarma.value_counts()
# Out:
# FALSA ALARMA         140
# URGENCIAS MEDICAS      9
# EMERGENCIA             9
# Name: clas_con_f_alarma, dtype: int64

# %% [markdown]
# Vemos que cuando la delegacion de inicio y delegacion de cierre son NA's al mismo tiempo, es porque se tiene una falsa alarma

# %% [markdown]
# Veamos el resto de los casos:

# %%
data[(data.delegacion_inicio.isna())&(data.clas_con_f_alarma != "FALSA ALARMA")]
# Out:
#                    folio fecha_creacion hora_creacion dia_semana  \
# 279857   C5/180822/03110     22/08/2018      09:31:00  Miércoles
# 432516   C5/180902/10676     02/09/2018      20:55:34    Domingo
# 432593   C5/180904/06600     04/09/2018      17:08:57     Martes
# 724961   C5/180810/05668     10/08/2018      15:40:00    Viernes
# 725605   C5/180811/01836     11/08/2018      05:15:00     Sábado
# 757942   C5/180825/00026     25/08/2018      00:02:00     Sábado
# 760762   GA/180831/06257     31/08/2018      15:40:30    Viernes
# 762401   C5/180819/10229     19/08/2018      18:45:00    Domingo
# 763211   C5/180821/10003     21/08/2018      21:58:00     Martes
# 764090   C5/180810/02590     10/08/2018      09:50:00    Viernes
# 764685   GA/180825/03568     25/08/2018      07:37:00     Sábado
# 765604   C5/180813/03454     13/08/2018      09:53:00      Lunes
# 766988   C5/180816/02692     16/08/2018      07:58:00     Jueves
# 767985   C5/180901/01045     01/09/2018      01:55:00     Sábado
# 1240537  C5/180903/00406     03/09/2018      01:21:23      Lunes
# 1240713  C5/180904/06469     04/09/2018      16:56:07     Martes
# 1240724  C5/180905/02822     05/09/2018      10:48:31  Miércoles
# 1259009  C5/180815/03552     15/08/2018      09:57:00  Miércoles
#
#                                              codigo_cierre fecha_cierre  \
# 279857   (D) El incidente reportado se registró en dos ...   22/08/2018
# 432516   (A) La unidad de atención a emergencias fue de...   03/09/2018
# 432593   (D) El incidente reportado se registró en dos ...   04/09/2018
# 724961   (D) El incidente reportado se registró en dos ...   10/08/2018
# 725605   (A) La unidad de atención a emergencias fue de...   11/08/2018
# 757942   (N) La unidad de atención a emergencias fue de...   25/08/2018
# 760762   (A) La unidad de atención a emergencias fue de...   31/08/2018
# 762401   (D) El incidente reportado se registró en dos ...   19/08/2018
# 763211   (A) La unidad de atención a emergencias fue de...   21/08/2018
# 764090   (A) La unidad de atención a emergencias fue de...   10/08/2018
# 764685   (A) La unidad de atención a emergencias fue de...   25/08/2018
# 765604   (A) La unidad de atención a emergencias fue de...   13/08/2018
# 766988   (A) La unidad de atención a emergencias fue de...   16/08/2018
# 767985   (D) El incidente reportado se registró en dos ...   01/09/2018
# 1240537  (N) La unidad de atención a emergencias fue de...   03/09/2018
# 1240713  (A) La unidad de atención a emergencias fue de...   04/09/2018
# 1240724  (A) La unidad de atención a emergencias fue de...   05/09/2018
# 1259009  (N) La unidad de atención a emergencias fue de...   15/08/2018
#
#          año_cierre  mes_cierre hora_cierre delegacion_inicio  \
# 279857         2018      Agosto    09:44:00               NaN
# 432516         2018  Septiembre    01:41:09               NaN
# 432593         2018  Septiembre    17:18:31               NaN
# 724961         2018      Agosto    16:02:00               NaN
# 725605         2018      Agosto    05:48:00               NaN
# 757942         2018      Agosto    02:41:00               NaN
# 760762         2018      Agosto    18:04:04               NaN
# 762401         2018      Agosto    19:15:00               NaN
# 763211         2018      Agosto    22:14:00               NaN
# 764090         2018      Agosto    12:19:00               NaN
# 764685         2018      Agosto    08:32:00               NaN
# 765604         2018      Agosto    13:27:00               NaN
# 766988         2018      Agosto    08:35:00               NaN
# 767985         2018  Septiembre    01:58:00               NaN
# 1240537        2018  Septiembre    01:45:38               NaN
# 1240713        2018  Septiembre    17:34:03               NaN
# 1240724        2018  Septiembre    16:15:12               NaN
# 1259009        2018      Agosto    10:29:00               NaN
#
#                             incidente_c4    latitud   longitud  \
# 279857             lesionado-atropellado  19.456380 -99.215270
# 432516   accidente-choque con lesionados  19.434509 -99.087715
# 432593   accidente-choque con lesionados  19.448690 -99.075480
# 724961   accidente-choque sin lesionados  19.448690 -99.075480
# 725605   accidente-choque sin lesionados  19.502880 -99.157130
# 757942   accidente-choque sin lesionados  19.418100 -99.074390
# 760762            accidente-motociclista  19.461880 -99.056060
# 762401   accidente-choque sin lesionados  19.448690 -99.075480
# 763211       accidente-vehiculo atrapado  19.530970 -99.171790
# 764090   accidente-choque sin lesionados  19.417450 -99.076040
# 764685   accidente-choque sin lesionados  19.418182 -99.079171
# 765604   accidente-choque con lesionados  19.510180 -99.105910
# 766988   accidente-choque sin lesionados  19.421120 -99.082450
# 767985            accidente-motociclista  19.412250 -99.056830
# 1240537  accidente-choque sin lesionados  19.433833 -99.087157
# 1240713  accidente-choque con lesionados  19.448690 -99.075480
# 1240724            lesionado-atropellado  19.527200 -99.171330
# 1259009           accidente-motociclista  19.444270 -99.218040
#
#          clas_con_f_alarma     tipo_entrada    delegacion_cierre  \
# 279857   URGENCIAS MEDICAS            ZELLO       MIGUEL HIDALGO
# 432516   URGENCIAS MEDICAS            RADIO  VENUSTIANO CARRANZA
# 432593   URGENCIAS MEDICAS            ZELLO    GUSTAVO A. MADERO
# 724961          EMERGENCIA  LLAMADA DEL 911  VENUSTIANO CARRANZA
# 725605          EMERGENCIA  LLAMADA DEL 911    GUSTAVO A. MADERO
# 757942          EMERGENCIA  LLAMADA DEL 911  VENUSTIANO CARRANZA
# 760762   URGENCIAS MEDICAS            RADIO    GUSTAVO A. MADERO
# 762401          EMERGENCIA  LLAMADA DEL 911  VENUSTIANO CARRANZA
# 763211          EMERGENCIA            ZELLO    GUSTAVO A. MADERO
# 764090          EMERGENCIA  LLAMADA DEL 911  VENUSTIANO CARRANZA
# 764685          EMERGENCIA            RADIO  VENUSTIANO CARRANZA
# 765604   URGENCIAS MEDICAS            RADIO    GUSTAVO A. MADERO
# 766988          EMERGENCIA            RADIO  VENUSTIANO CARRANZA
# 767985   URGENCIAS MEDICAS  LLAMADA DEL 911            IZTACALCO
# 1240537         EMERGENCIA  LLAMADA DEL 911  VENUSTIANO CARRANZA
# 1240713  URGENCIAS MEDICAS            RADIO  VENUSTIANO CARRANZA
# 1240724  URGENCIAS MEDICAS            RADIO    GUSTAVO A. MADERO
# 1259009  URGENCIAS MEDICAS  LLAMADA DEL 911       MIGUEL HIDALGO
#
#                          geopoint  mes
# 279857      19.45638,-99.21526992    8
# 432516       19.434509,-99.087715    9
# 432593   19.44869004,-99.07548012    9
# 724961   19.44869004,-99.07548012    8
# 725605   19.50288003,-99.15712992    8
# 757942   19.41810003,-99.07439004    8
# 760762   19.46187999,-99.05605992    8
# 762401   19.44869004,-99.07548012    8
# 763211   19.53097002,-99.17178984    8
# 764090   19.41744996,-99.07603992    8
# 764685   19.41818176,-99.07917126    8
# 765604   19.51018002,-99.10590984    8
# 766988         19.42112,-99.08245    8
# 767985   19.41225003,-99.05682996    9
# 1240537      19.433833,-99.087157    9
# 1240713  19.44869004,-99.07548012    9
# 1240724  19.52720001,-99.17133012    9
# 1259009  19.44426996,-99.21804012    8

# %% [markdown]
# Cuando se tiene que delegacion_inicio es NA y que NO es una falsa alarma, entonces sí se tiene un valor en delegacion_cierre. Se propone utilizar el valor de delegacion_cierre para imputar los valores faltantes de delegacion_inicio

# %% [markdown]
# #### Longitud y latitud

# %% [markdown]
# Veamos ahora los valores faltantes en longitud y latitud

# %%
data[(data.longitud.isna()) & (data.latitud.isna())]
# Out:
#                   folio fecha_creacion hora_creacion dia_semana  \
# 284050  C5/181231/02925     31/12/2018      10:52:07      Lunes
# 284051  C5/181231/06798     31/12/2018      18:28:05      Lunes
# 284052  C5/181231/02638     31/12/2018      10:15:06      Lunes
# 284053  C5/181231/08158     31/12/2018      21:09:53      Lunes
# 284054  C5/181231/07818     31/12/2018      20:27:37      Lunes
# ...                 ...            ...           ...        ...
# 714663  C5/181231/08750     31/12/2018      22:01:23      Lunes
# 714665  C5/181231/02598     31/12/2018      10:09:23      Lunes
# 714667  C5/181231/07779     31/12/2018      20:20:43      Lunes
# 714695  C5/181231/06803     31/12/2018      18:27:50      Lunes
# 714697  C5/181231/06872     31/12/2018      18:36:43      Lunes
#
#                                             codigo_cierre fecha_cierre  \
# 284050  (N) La unidad de atención a emergencias fue de...   31/12/2018
# 284051  (D) El incidente reportado se registró en dos ...   31/12/2018
# 284052  (A) La unidad de atención a emergencias fue de...   31/12/2018
# 284053  (D) El incidente reportado se registró en dos ...   31/12/2018
# 284054  (N) La unidad de atención a emergencias fue de...   31/12/2018
# ...                                                   ...          ...
# 714663  (A) La unidad de atención a emergencias fue de...   31/12/2018
# 714665  (D) El incidente reportado se registró en dos ...   31/12/2018
# 714667  (D) El incidente reportado se registró en dos ...   31/12/2018
# 714695  (D) El incidente reportado se registró en dos ...   31/12/2018
# 714697  (D) El incidente reportado se registró en dos ...   31/12/2018
#
#         año_cierre mes_cierre hora_cierre  delegacion_inicio  \
# 284050        2018  Diciembre    11:25:43           COYOACAN
# 284051        2018  Diciembre    18:51:17         CUAUHTEMOC
# 284052        2018  Diciembre    12:34:37            TLAHUAC
# 284053        2018  Diciembre    21:12:53       AZCAPOTZALCO
# 284054        2018  Diciembre    20:46:21     ALVARO OBREGON
# ...            ...        ...         ...                ...
# 714663        2018  Diciembre    22:32:17  GUSTAVO A. MADERO
# 714665        2018  Diciembre    10:14:18         IZTAPALAPA
# 714667        2018  Diciembre    20:22:20           COYOACAN
# 714695        2018  Diciembre    18:34:55         CUAUHTEMOC
# 714697        2018  Diciembre    18:44:44         CUAUHTEMOC
#
#                            incidente_c4  latitud  longitud  clas_con_f_alarma  \
# 284050  accidente-choque sin lesionados      NaN       NaN         EMERGENCIA
# 284051  accidente-choque con lesionados      NaN       NaN  URGENCIAS MEDICAS
# 284052  accidente-choque con lesionados      NaN       NaN  URGENCIAS MEDICAS
# 284053            lesionado-atropellado      NaN       NaN  URGENCIAS MEDICAS
# 284054  accidente-choque sin lesionados      NaN       NaN         EMERGENCIA
# ...                                 ...      ...       ...                ...
# 714663           accidente-motociclista      NaN       NaN  URGENCIAS MEDICAS
# 714665  accidente-choque sin lesionados      NaN       NaN         EMERGENCIA
# 714667            lesionado-atropellado      NaN       NaN  URGENCIAS MEDICAS
# 714695  detención ciudadana-atropellado      NaN       NaN             DELITO
# 714697  detención ciudadana-atropellado      NaN       NaN             DELITO
#
#            tipo_entrada  delegacion_cierre geopoint  mes
# 284050  LLAMADA DEL 911           COYOACAN      NaN   12
# 284051  LLAMADA DEL 911         CUAUHTEMOC      NaN   12
# 284052  LLAMADA DEL 911            TLAHUAC      NaN   12
# 284053  LLAMADA DEL 911       AZCAPOTZALCO      NaN   12
# 284054  LLAMADA DEL 911     ALVARO OBREGON      NaN   12
# ...                 ...                ...      ...  ...
# 714663  LLAMADA DEL 911  GUSTAVO A. MADERO      NaN   12
# 714665  LLAMADA DEL 911         IZTAPALAPA      NaN   12
# 714667  LLAMADA DEL 911           COYOACAN      NaN   12
# 714695  LLAMADA DEL 911         CUAUHTEMOC      NaN   12
# 714697  LLAMADA DEL 911         CUAUHTEMOC      NaN   12
#
# [432 rows x 18 columns]

# %%
data[(data.longitud.isna()) & (data.latitud.notna())]
# Out:
#                   folio fecha_creacion hora_creacion dia_semana  \
# 284145  C5/181231/06094     31/12/2018      17:03:39      Lunes
# 436981  C5/181231/06971     31/12/2018      18:46:55      Lunes
# 714661  GA/181231/04533     31/12/2018      14:15:47      Lunes
#
#                                             codigo_cierre fecha_cierre  \
# 284145  (A) La unidad de atención a emergencias fue de...   31/12/2018
# 436981  (N) La unidad de atención a emergencias fue de...   31/12/2018
# 714661  (A) La unidad de atención a emergencias fue de...   31/12/2018
#
#         año_cierre mes_cierre hora_cierre  delegacion_inicio  \
# 284145        2018  Diciembre    17:21:08      BENITO JUAREZ
# 436981        2018  Diciembre    19:00:13         IZTAPALAPA
# 714661        2018  Diciembre    17:16:38  GUSTAVO A. MADERO
#
#                            incidente_c4  latitud  longitud  clas_con_f_alarma  \
# 284145           accidente-motociclista  193.815       NaN  URGENCIAS MEDICAS
# 436981  accidente-choque sin lesionados  193.446       NaN         EMERGENCIA
# 714661  accidente-choque sin lesionados  195.303       NaN         EMERGENCIA
#
#             tipo_entrada  delegacion_cierre geopoint  mes
# 284145   LLAMADA DEL 911      BENITO JUAREZ      NaN   12
# 436981   LLAMADA DEL 911         IZTAPALAPA      NaN   12
# 714661  BOTÓN DE AUXILIO  GUSTAVO A. MADERO      NaN   12

# %%
data[(data.longitud.notna()) & (data.latitud.isna())]
# Out:
#                   folio fecha_creacion hora_creacion dia_semana  \
# 284110  C5/181231/01210     31/12/2018      06:02:10      Lunes
# 284125  C5/181231/05350     31/12/2018      15:42:11      Lunes
# 436964  C5/181231/06210     31/12/2018      17:18:40      Lunes
# 436990  C5/181231/01068     31/12/2018      04:51:42      Lunes
# 437000  C5/181231/05354     31/12/2018      15:42:14      Lunes
# 437042  C5/181231/05353     31/12/2018      15:41:59      Lunes
# 437075  C5/181231/00961     31/12/2018      04:08:37      Lunes
# 714449  C5/181231/05744     31/12/2018      16:22:20      Lunes
# 714483  C5/181231/00956     31/12/2018      04:06:15      Lunes
# 714513  C5/181231/04311     31/12/2018      13:34:03      Lunes
# 714585  C5/181231/06875     31/12/2018      18:36:26      Lunes
#
#                                             codigo_cierre fecha_cierre  \
# 284110  (D) El incidente reportado se registró en dos ...   31/12/2018
# 284125  (D) El incidente reportado se registró en dos ...   31/12/2018
# 436964  (A) La unidad de atención a emergencias fue de...   31/12/2018
# 436990  (D) El incidente reportado se registró en dos ...   31/12/2018
# 437000  (D) El incidente reportado se registró en dos ...   31/12/2018
# 437042  (D) El incidente reportado se registró en dos ...   31/12/2018
# 437075  (D) El incidente reportado se registró en dos ...   31/12/2018
# 714449  (A) La unidad de atención a emergencias fue de...   31/12/2018
# 714483  (A) La unidad de atención a emergencias fue de...   31/12/2018
# 714513  (A) La unidad de atención a emergencias fue de...   31/12/2018
# 714585  (D) El incidente reportado se registró en dos ...   31/12/2018
#
#         año_cierre mes_cierre hora_cierre delegacion_inicio  \
# 284110        2018  Diciembre    06:05:35        IZTAPALAPA
# 284125        2018  Diciembre    15:50:06        CUAUHTEMOC
# 436964        2018  Diciembre    19:09:52         IZTACALCO
# 436990        2018  Diciembre    05:18:29      AZCAPOTZALCO
# 437000        2018  Diciembre    15:49:03        CUAUHTEMOC
# 437042        2018  Diciembre    15:49:27        CUAUHTEMOC
# 437075        2018  Diciembre    04:18:48      AZCAPOTZALCO
# 714449        2018  Diciembre    18:10:39        IZTAPALAPA
# 714483        2018  Diciembre    06:22:55      AZCAPOTZALCO
# 714513        2018  Diciembre    16:01:07           TLAHUAC
# 714585        2018  Diciembre    18:40:48        CUAUHTEMOC
#
#                            incidente_c4  latitud  longitud  clas_con_f_alarma  \
# 284110           accidente-motociclista      NaN  -990.369  URGENCIAS MEDICAS
# 284125  accidente-choque con lesionados      NaN  -991.692  URGENCIAS MEDICAS
# 436964           accidente-motociclista      NaN  -990.765  URGENCIAS MEDICAS
# 436990  accidente-choque con lesionados      NaN  -991.764  URGENCIAS MEDICAS
# 437000  accidente-choque con lesionados      NaN  -991.692  URGENCIAS MEDICAS
# 437042  accidente-choque con lesionados      NaN  -991.692  URGENCIAS MEDICAS
# 437075  accidente-choque con lesionados      NaN  -991.764  URGENCIAS MEDICAS
# 714449  accidente-choque sin lesionados      NaN  -990.495         EMERGENCIA
# 714483  accidente-choque con lesionados      NaN  -991.764  URGENCIAS MEDICAS
# 714513  accidente-choque sin lesionados      NaN  -989.595         EMERGENCIA
# 714585            lesionado-atropellado      NaN   -99.153  URGENCIAS MEDICAS
#
#            tipo_entrada delegacion_cierre geopoint  mes
# 284110  LLAMADA DEL 911        IZTAPALAPA      NaN   12
# 284125  LLAMADA DEL 911        CUAUHTEMOC      NaN   12
# 436964            RADIO         IZTACALCO      NaN   12
# 436990  LLAMADA DEL 911      AZCAPOTZALCO      NaN   12
# 437000  LLAMADA DEL 911        CUAUHTEMOC      NaN   12
# 437042  LLAMADA DEL 911        CUAUHTEMOC      NaN   12
# 437075  LLAMADA DEL 911      AZCAPOTZALCO      NaN   12
# 714449  LLAMADA DEL 911        IZTAPALAPA      NaN   12
# 714483  LLAMADA DEL 911      AZCAPOTZALCO      NaN   12
# 714513  LLAMADA DEL 911           TLAHUAC      NaN   12
# 714585  LLAMADA DEL 911        CUAUHTEMOC      NaN   12

# %%
data[(data.longitud.isna())  | (data.latitud.isna())].isna().sum()
# Out:
# folio                  0
# fecha_creacion         0
# hora_creacion          0
# dia_semana             0
# codigo_cierre          0
# fecha_cierre           0
# año_cierre             0
# mes_cierre             0
# hora_cierre            0
# delegacion_inicio      0
# incidente_c4           0
# latitud              443
# longitud             435
# clas_con_f_alarma      0
# tipo_entrada           0
# delegacion_cierre      0
# geopoint             446
# mes                    0
# dtype: int64

# %% [markdown]
# Vemos que NO siempre faltan ambos puntos de coordenadas, pero siempre que falta alguno, la variable "geopoint" es na. En este caso, podríamos imputar los valores faltantes con el centroide de la delegación en la que se cierra.

# %% [markdown]
# ### Gráficas

# %%
f = plt.subplots(figsize = (6,7))

sns.scatterplot(data = data_clean[data_clean['año_cierre'] == 2019] , y = "latitud", x = "longitud", hue = "delegacion_cierre")

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
